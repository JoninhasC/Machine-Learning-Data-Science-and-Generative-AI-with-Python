# %%
# %matplotlib inline

import numpy as np
from pylab import *

def de_mean(x):
    xmean = mean(x)
    return [xi - xmean for xi in x]

def covariance(x, y):
    n = len(x)
    return dot(de_mean(x), de_mean(y)) / (n-1)

pageSpeeds = np.random.normal(3.0, 1.0, 1000)
purchaseAmount = np.random.normal(50.0, 10.0, 1000)

scatter(pageSpeeds, purchaseAmount)

covariance (pageSpeeds, purchaseAmount)
# Out:
# np.float64(0.058130525565583395)

# %%
purchaseAmount = np.random.normal(50.0, 10.0, 1000) / pageSpeeds

scatter(pageSpeeds, purchaseAmount)

covariance (pageSpeeds, purchaseAmount)
# Out:
# np.float64(-9.774844371457203)

# %%
def correlation(x, y):
    stddevx = x.std()
    stddevy = y.std()
    return covariance(x,y) / stddevx / stddevy  #In real life you'd check for divide by zero here

correlation(pageSpeeds, purchaseAmount)
# Out:
# np.float64(-0.47903993930709987)

# %%
np.corrcoef(pageSpeeds, purchaseAmount)
# Out:
# array([[ 1.       , -0.4785609],
#        [-0.4785609,  1.       ]])

# %%
purchaseAmount = 100 - pageSpeeds * 3

scatter(pageSpeeds, purchaseAmount)

correlation (pageSpeeds, purchaseAmount)
# Out:
# np.float64(-1.001001001001001)

# %%
cov_custom = covariance(pageSpeeds, purchaseAmount)
print(f"Custom Covariance: {cov_custom}")
# Out:
# Custom Covariance: -3.048288195085517

# %%
cov_matrix = np.cov(pageSpeeds, purchaseAmount)
print(f"NumPy Covariance Matrix:\n{cov_matrix}")
# Out:
# NumPy Covariance Matrix:
# [[ 1.01609607 -3.0482882 ]
#  [-3.0482882   9.14486459]]
