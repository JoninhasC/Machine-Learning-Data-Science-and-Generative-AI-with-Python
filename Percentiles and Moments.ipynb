# %%
# %matplotlib inline 
import numpy as np
import matplotlib.pyplot as plt

vals = np.random.normal(0, 0.5, 10000)

plt.hist(vals, 50)

plt.show()

# %%
np.percentile(vals, 50)
# Out:
# np.float64(0.0016070066395814271)

# %%
np.percentile(vals, 20)
# Out:
# np.float64(-0.4187598873484574)

# %%
np.percentile(vals, 90)
# Out:
# np.float64(0.6282213689504631)

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

vals = np.random.normal(0, 0.5, 10000)

plt.hist(vals, 50)
plt.show()

# %%
np.mean(vals)
# Out:
# np.float64(-0.008012159869066436)

# %%
np.var(vals)
# Out:
# np.float64(0.2474154688099767)

# %%
import scipy.stats as sp
sp.skew(vals)
# Out:
# np.float64(0.020446571090109368)

# %%
sp.kurtosis(vals)
# Out:
# np.float64(-0.01159311279741937)
